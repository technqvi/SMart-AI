# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer


from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot  as plt
import os

# %%
print(xgb.__version__)
# Out:
# 1.7.3

# %%
# dateTimeCols=['open_datetime','response_datetime','resolved_datetime','close_datetime']
dateTimeCols=['open_datetime','close_datetime']

cateFeatures=['product_type','brand','incident_type','service_type','is_failure_type','sla']

# numericFeatures=['count_detail','open_to_close_hour','response_to_resolved_hour','open_to_response_hour','resolved_to_close_hour']
numericFeatures=['count_detail','open_to_close_hour']

colLabel='severity_label'


calLabelRefInfo=[colLabel,'severity_name']

colFeatures=cateFeatures+numericFeatures

cols=[colLabel]+colFeatures

print(cols)

from_date='2023-01-10'
# Out:
# ['severity_label', 'product_type', 'brand', 'incident_type', 'service_type', 'is_failure_type', 'sla', 'count_detail', 'open_to_close_hour']

# %% [markdown]
# # Load and Prepare Data

# %%
df_incident = pd.read_csv('incident_data.csv',parse_dates=dateTimeCols)
print(f"Incident From {df_incident['open_datetime'].min()} To {df_incident['open_datetime'].max()}")
df_incident=df_incident.query("open_datetime>=@from_date")

df_incident=df_incident[cols]
print(df_incident.info())
df_incident.tail()
# Out:
# Incident From 2020-03-15 13:36:00 To 2023-02-01 06:40:00
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 0 to 96
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   severity_label      97 non-null     int64
#  1   product_type        97 non-null     object
#  2   brand               97 non-null     object
#  3   incident_type       97 non-null     object
#  4   service_type        97 non-null     object
#  5   is_failure_type     97 non-null     bool
#  6   sla                 97 non-null     object
#  7   count_detail        97 non-null     int64
#  8   open_to_close_hour  97 non-null     float64
# dtypes: bool(1), float64(1), int64(2), object(5)
# memory usage: 6.9+ KB
# None
#     severity_label product_type   brand            incident_type service_type  \
# 92               2     Hardware  Oracle  Hard Disk Drive Failure     Incident
# 93               3     Software  VMWare                 Software     Incident
# 94               3       Server  Oracle              CPU Failure     Incident
# 95               2       Server     HPE  Hard Disk Drive Failure     Incident
# 96               3     Software  VMWare                 Software     Incident
#
#     is_failure_type                        sla  count_detail  \
# 92            False  24x7 4Hrs Resolution Time             1
# 93            False    24x7 4Hrs Response Time             2
# 94            False  24x7 4Hrs Resolution Time             3
# 95            False    24x7 4Hrs Response Time             2
# 96            False    24x7 4Hrs Response Time             2
#
#     open_to_close_hour
# 92            1.983333
# 93            2.350000
# 94            3.000000
# 95            8.583333
# 96           19.983333

# %% [markdown]
# # Process features and target class

# %%
# cateFeatures_cateLabel=cateFeatures.copy()+[colLabel]
print(f"{cateFeatures} and {colLabel}")
X = df_incident.loc[:,colFeatures]
X[cateFeatures]=X[cateFeatures].astype("category") 

print(X.info())
X.sample(10)
# Out:
# ['product_type', 'brand', 'incident_type', 'service_type', 'is_failure_type', 'sla'] and severity_label
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 0 to 96
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_type        97 non-null     category
#  1   brand               97 non-null     category
#  2   incident_type       97 non-null     category
#  3   service_type        97 non-null     category
#  4   is_failure_type     97 non-null     category
#  5   sla                 97 non-null     category
#  6   count_detail        97 non-null     int64
#  7   open_to_close_hour  97 non-null     float64
# dtypes: category(6), float64(1), int64(1)
# memory usage: 4.4 KB
# None
#    product_type        brand            incident_type service_type  \
# 27     Hardware       Oracle           Backup Failure      Request
# 12       Server          HPE         General Incident     Incident
# 5        Server          HPE         General Incident     Incident
# 18       Switch        Cisco  Network Adapter Failure     Incident
# 50      Storage       NetApp         General Incident     Incident
# 84     Software  Trend Micro     Configuration Change      Request
# 22     Firewall    Palo Alto                 Software     Incident
# 92     Hardware       Oracle  Hard Disk Drive Failure     Incident
# 71       Server          HPE           Memory Failure     Incident
# 34      Storage       NetApp  Controller/Node Failure     Incident
#
#    is_failure_type                        sla  count_detail  \
# 27           False  24x7 4Hrs Resolution Time             1
# 12           False  24x7 4Hrs Resolution Time             2
# 5            False  24x7 4Hrs Resolution Time             5
# 18            True     8x5 4Hrs Response Time             8
# 50           False  24x7 6Hrs Resolution Time             2
# 84           False    24x7 4Hrs Response Time             1
# 22           False  24x7 4Hrs Resolution Time             1
# 92           False  24x7 4Hrs Resolution Time             1
# 71           False  24x7 4Hrs Resolution Time             3
# 34           False    24x7 4Hrs Response Time             5
#
#     open_to_close_hour
# 27           31.433333
# 12            8.450000
# 5            92.866667
# 18           56.916667
# 50           17.866667
# 84            4.066667
# 22            0.366667
# 92            1.983333
# 71           36.500000
# 34           20.433333

# %%
y=df_incident.loc[:,colLabel]
print(y.info())
y.sample(10)
# y=y.astype("category")
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 97 entries, 0 to 96
# Series name: severity_label
# Non-Null Count  Dtype
# --------------  -----
# 97 non-null     int64
# dtypes: int64(1)
# memory usage: 1.5 KB
# None
# 89    2
# 37    2
# 69    2
# 59    3
# 56    2
# 86    2
# 91    3
# 67    2
# 33    3
# 30    3
# Name: severity_label, dtype: int64

# %%
# label_encoder = LabelEncoder()
# y = label_encoder.fit_transform(y)

# print(label_encoder.classes_)

# print(y[-5:])

# %% [markdown]
# # Load Model Model to Predict

# %%
model_xg = xgb.Booster()  # init model
model_xg.load_model('model.bst')  # load data

# %%
dtest = xgb.DMatrix(data=X,label=y,enable_categorical=True)
y_pred_values = model_xg.predict(dtest)
yPredictionsList = [round(value) for value in y_pred_values]

accuracy_xg = accuracy_score(y, yPredictionsList)
print("XGBoost Accuracy: %.2f%%" % (accuracy_xg * 100.0))
# Out:
# XGBoost Accuracy: 61.86%

# %%
yPrediction=pd.Series(yPredictionsList).to_frame("severity_prediction")

# %%
dfAll=pd.concat([yPrediction,y,X],axis=1)
dfAll.info()
dfAll
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   severity_prediction  97 non-null     int64
#  1   severity_label       97 non-null     int64
#  2   product_type         97 non-null     category
#  3   brand                97 non-null     category
#  4   incident_type        97 non-null     category
#  5   service_type         97 non-null     category
#  6   is_failure_type      97 non-null     category
#  7   sla                  97 non-null     category
#  8   count_detail         97 non-null     int64
#  9   open_to_close_hour   97 non-null     float64
# dtypes: category(6), float64(1), int64(3)
# memory usage: 5.3 KB
#     severity_prediction  severity_label product_type   brand  \
# 0                     2               2       Server     HPE
# 1                     3               2      Storage     EMC
# 2                     2               2       Server     HPE
# 3                     3               3       Server     HPE
# 4                     2               2      Storage  NetApp
# ..                  ...             ...          ...     ...
# 92                    2               2     Hardware  Oracle
# 93                    2               3     Software  VMWare
# 94                    2               3       Server  Oracle
# 95                    2               2       Server     HPE
# 96                    2               3     Software  VMWare
#
#               incident_type service_type is_failure_type  \
# 0   Hard Disk Drive Failure     Incident           False
# 1   Hard Disk Drive Failure     Incident           False
# 2            Memory Failure     Incident           False
# 3          General Incident     Incident           False
# 4   Hard Disk Drive Failure     Incident           False
# ..                      ...          ...             ...
# 92  Hard Disk Drive Failure     Incident           False
# 93                 Software     Incident           False
# 94              CPU Failure     Incident           False
# 95  Hard Disk Drive Failure     Incident           False
# 96                 Software     Incident           False
#
#                           sla  count_detail  open_to_close_hour
# 0     24x7 4Hrs Response Time             2            5.333333
# 1      8x5 4Hrs Response Time             2           30.450000
# 2     24x7 4Hrs Response Time             2            6.833333
# 3   24x7 4Hrs Resolution Time             8           48.700000
# 4     24x7 4Hrs Response Time             1           22.650000
# ..                        ...           ...                 ...
# 92  24x7 4Hrs Resolution Time             1            1.983333
# 93    24x7 4Hrs Response Time             2            2.350000
# 94  24x7 4Hrs Resolution Time             3            3.000000
# 95    24x7 4Hrs Response Time             2            8.583333
# 96    24x7 4Hrs Response Time             2           19.983333
#
# [97 rows x 10 columns]
